# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(-2, 2, 200)
y = np.sin(x)

# %%
plt.plot(x, y)

# %%
import matplotlib as mpl
mpl.matplotlib_fname()
# Out:
# '/home/zejian/.config/matplotlib/matplotlibrc'

# %%
mpl.get_configdir()
# Out:
# '/home/zejian/.config/matplotlib'
